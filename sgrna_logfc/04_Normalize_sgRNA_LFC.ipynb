# %% [markdown]
# ### Normalize and correct sgRNA Log Fold Change data
# #### adapted from Fortin et al, 2019
# #### by Stefanus Bernard

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### List of function

# %%
# function to normalize sgRNA LFC by median of all sgRNA (ignoring the NA)
def normalize_column(col):
    median = np.nanmedian(col)
    centered = col - median
    mad = np.nanmedian(np.abs(centered))
    if mad == 0 or np.isnan(mad):
        return centered
    return centered / mad

# function to scaled LFC by the absolute average LFC value across cell lines for guides targeting essential genes (Achilles Common Essential Controls)
def scale_essential(df):
    common_essential = pd.read_csv('AchillesCommonEssentialControls_25Q2.csv')
    common_essential[['gene', 'accession']] = common_essential['Gene'].str.split(' ', n = 1, expand = True)
    common_essential = common_essential[['gene', 'accession']]

    list_common_essential = list(common_essential['gene'])
    list_common_essential

    # subset guides targeting essential genes
    ess_guides = df.loc[df.index.get_level_values('gene').isin(list_common_essential)]

    # compute average LFC across cell lines for each essential guides
    ess_avg = ess_guides.mean(axis = 1)

    # take absolute value and average across guides
    scale_factor = np.mean(np.abs(ess_avg))
    print('Scale factor: ', scale_factor)

    df_scaled = df / scale_factor
    
    return df_scaled, list_common_essential

def sanity_check_scale_essential(df, df_scaled, list_common_essential):
    # Sanity check for the scaling LFC method
    ess_before = df.loc[df.index.get_level_values('gene').isin(list_common_essential)].stack().values
    ess_after = df_scaled.loc[df_scaled.index.get_level_values('gene').isin(list_common_essential)].stack().values

    plt.boxplot([ess_before, ess_after], labels = ['Before', 'After'])
    plt.ylabel('logFC guides targeting common essential genes')
    plt.show()
    
# function to correct LFC for gene copy number alterations 

# function to average the row of the spacer
def mean_row(df):
    df['mean'] = df.mean(axis = 1)
    df = df['mean']
    return df

# %% [markdown]
# #### Process Avana LFC and library data

# %%
lfc_data = pd.read_csv("AvanaLogfoldChange_25Q2.csv")
lfc_data = lfc_data.rename(columns={lfc_data.columns[0]: 'spacer'})
lfc_data.head(25)
# Out:
#                   spacer  Colo699-311cas9-RepA-p6_Avana-4  \
# 0   AAAAAAATCCAGCAATGCAG                        -0.171066
# 1   AAAAAACCCGTAGATAGCCT                        -0.402138
# 2   AAAAAAGAAGAAAAAACCAG                        -0.410449
# 3   AAAAAAGCTCAAGAAGGAGG                        -0.391271
# 4   AAAAAAGGCTGTAAAAGCGT                        -0.529545
# 5   AAAAAAGGGCTCCAAAAAGG                        -0.597079
# 6   AAAAACAACACATCAGAGCG                         0.381416
# 7   AAAAACTCTGGGAAATGACT                         0.334391
# 8   AAAAAGACAACCTCGCCCTG                         0.108744
# 9   AAAAAGAGCTGTTTGAACAA                        -0.084525
# 10  AAAAAGATCATGATTGAGCG                        -0.568177
# 11  AAAAAGCCTGGATAACGGAA                        -0.332792
# 12  AAAAAGCTGGGTTAGAAGCG                         0.069453
# 13  AAAAAGCTTCCGCCTGATGG                         0.059982
# 14  AAAAATCCGGACAATGGTGG                        -0.187548
# 15  AAAAATCCTAAAATAAAATA                         0.104390
# 16  AAAAATCCTCTGAAGCCGCA                        -0.452636
# 17  AAAAATGCCAAAAAGCAAGC                        -0.059794
# 18  AAAAATGCGCAAATTCAGCG                        -0.412649
# 19  AAAAATGCTGAATTTCCCAG                         0.204067
# 20  AAAAATGGTTGACCTCACCC                         0.073685
# 21  AAAAATGTATACTAACCAGG                        -0.146057
# 22  AAAAATTGAGAGTAACACAG                         1.065735
# 23  AAAACAATCTCACCTCTGGG                         0.610260
# 24  AAAACACAGCAATCTCCAGA                         0.086488
#
#     Colo699-311cas9-RepB-p6_Avana-4  HSB-2-311cas9_RepA_p4_Avana-3  \
# 0                          0.029490                       0.069540
# 1                         -0.307266                      -0.313058
# 2                         -0.612478                      -0.212222
# 3                         -0.523115                      -0.747823
# 4                         -0.078421                      -0.177395
# 5                          0.196256                      -0.442051
# 6                         -0.204037                      -0.303099
# 7                          0.231206                       0.208982
# 8                          0.099787                       0.444292
# 9                          0.066873                      -0.253916
# 10                        -0.437534                      -0.612772
# 11                        -0.017003                      -0.729069
# 12                        -0.031014                      -0.502445
# 13                         0.235905                       0.188928
# 14                        -0.250863                      -0.307269
# 15                         0.310108                      -0.463970
# 16                        -0.374176                       0.563637
# 17                        -0.574048                      -0.050337
# 18                        -0.195396                       0.215648
# 19                         0.044015                      -0.269963
# 20                         0.252327                      -0.044739
# 21                        -0.230660                       0.234513
# 22                         0.109542                      -0.185020
# 23                         0.631959                      -0.074805
# 24                         0.276552                      -0.346827
#
#     HSB-2-311cas9_RepB_p4_Avana-3  NCIH1339-311Cas9_RepA_p6_Avana-3  \
# 0                        0.162750                          0.237938
# 1                       -0.433916                         -0.572646
# 2                        0.136822                         -0.588377
# 3                       -0.443279                         -0.652751
# 4                       -0.709120                         -0.063580
# 5                       -0.489512                         -0.207339
# 6                       -0.172987                          0.136454
# 7                       -0.238882                         -0.247617
# 8                        0.007283                         -0.231494
# 9                        0.098424                          0.055886
# 10                      -0.509406                         -1.662148
# 11                      -0.660092                         -0.504399
# 12                      -0.456994                          0.317126
# 13                      -0.123786                          0.051959
# 14                      -0.185913                          0.138238
# 15                      -0.255386                         -0.465329
# 16                      -0.283750                         -0.625523
# 17                       0.425901                         -0.097677
# 18                      -0.195998                         -0.126155
# 19                      -0.032627                         -0.852911
# 20                      -0.149569                         -1.103349
# 21                      -0.248158                         -0.452176
# 22                      -0.142543                          0.050175
# 23                      -0.387938                         -0.121383
# 24                      -0.159589                          0.254162
#
#     NCIH1339-311Cas9_RepB_p6_Avana-3  HEL-311Cas9_RepA_p4_Avana-3  \
# 0                           0.229052                    -0.173349
# 1                          -0.556764                    -0.705799
# 2                          -0.974504                     0.459130
# 3                           0.126859                    -0.867980
# 4                          -0.467151                     0.234004
# 5                          -0.239894                    -0.875915
# 6                          -0.488989                     0.407917
# 7                           0.030078                     0.372719
# 8                           0.242598                    -0.699215
# 9                           0.177427                     0.056252
# 10                         -1.276817                     0.054388
# 11                         -0.572786                     0.164896
# 12                         -0.171858                    -0.373025
# 13                         -0.265384                    -0.052591
# 14                         -0.572454                    -0.783204
# 15                         -0.478726                    -0.161118
# 16                         -0.825641                     0.279727
# 17                         -0.792605                     0.091672
# 18                         -0.357773                    -0.469619
# 19                         -1.071009                    -0.057773
# 20                          0.014677                    -0.004059
# 21                         -0.753762                     0.249663
# 22                         -0.233577                    -0.217521
# 23                          0.241387                    -0.777349
# 24                         -0.074066                    -0.205608
#
#     HEL-311Cas9_RepB_p4_Avana-3  HEL9217-311Cas9_RepA_p6_Avana-3  ...  \
# 0                      0.156643                         0.107993  ...
# 1                     -0.314606                        -0.209826  ...
# 2                      0.696312                         0.176283  ...
# 3                     -0.185511                         0.051901  ...
# 4                     -0.271095                         0.193193  ...
# 5                      0.084434                        -0.153561  ...
# 6                      0.625015                        -0.043604  ...
# 7                      0.573196                         0.025043  ...
# 8                      0.081067                         0.227647  ...
# 9                     -0.018906                         0.108850  ...
# 10                    -0.112187                        -0.278944  ...
# 11                     0.235788                         0.069376  ...
# 12                    -0.334518                        -0.146167  ...
# 13                     0.536677                        -0.146033  ...
# 14                    -0.148503                        -0.199979  ...
# 15                     0.588437                        -0.446598  ...
# 16                     0.490598                         0.169439  ...
# 17                     0.544430                         0.193962  ...
# 18                     0.151241                         0.221228  ...
# 19                     0.052171                        -0.226558  ...
# 20                     0.072037                        -0.323841  ...
# 21                    -0.477163                        -0.053166  ...
# 22                    -1.179493                        -0.015241  ...
# 23                    -0.137124                        -0.340604  ...
# 24                     0.181773                         0.022812  ...
#
#     SNU977-311Cas9-AVANA-RepA-p6_Avana-4  \
# 0                              -0.433790
# 1                              -0.563867
# 2                              -0.891883
# 3                              -0.501404
# 4                              -0.972852
# 5                              -0.080975
# 6                              -1.471265
# 7                              -0.252516
# 8                              -0.539427
# 9                               0.447708
# 10                             -0.535104
# 11                             -0.566755
# 12                              0.018576
# 13                             -0.000316
# 14                              0.176094
# 15                              0.457814
# 16                             -1.251732
# 17                             -0.302123
# 18                              0.051377
# 19                              0.230688
# 20                              0.364721
# 21                              0.483239
# 22                              0.576709
# 23                             -0.656435
# 24                              0.606421
#
#     SNU977-311Cas9-AVANA-RepB-p6_Avana-4  HMMME-311cas9-RepA-p6_Avana-4  \
# 0                              -0.709138                      -0.580378
# 1                              -0.484689                       0.159082
# 2                              -0.020638                      -1.392148
# 3                              -0.422998                       0.219032
# 4                              -0.260724                       0.118860
# 5                              -0.083456                      -0.711989
# 6                              -0.578224                       0.142722
# 7                               0.023167                       0.348881
# 8                               0.338899                      -0.554798
# 9                               0.405770                       0.034198
# 10                             -1.243515                      -0.396489
# 11                              0.392568                      -0.422995
# 12                             -0.059579                       0.325297
# 13                             -0.265017                       0.621237
# 14                             -0.597652                      -0.640480
# 15                             -0.055967                       0.766551
# 16                             -0.438535                      -2.518209
# 17                             -0.444847                       0.700584
# 18                              0.089178                      -0.043043
# 19                              0.225923                      -0.186188
# 20                             -0.357673                      -0.083159
# 21                             -0.303502                      -0.413421
# 22                              1.002124                       0.171443
# 23                             -0.322218                      -0.515154
# 24                             -0.486190                      -0.020201
#
#     HMMME-311cas9-RepB-p6_Avana-4  JVE528-311cas9-RepB-p6_Avana-4  \
# 0                       -0.268531                        0.058415
# 1                       -0.080677                       -0.283203
# 2                       -1.293585                       -0.268365
# 3                       -0.162117                       -0.621547
# 4                        0.248156                       -0.121191
# 5                       -0.899371                        0.318502
# 6                        0.101824                       -0.295583
# 7                        0.520460                       -0.340950
# 8                       -0.266942                       -0.016523
# 9                        0.355359                       -0.121250
# 10                      -1.078285                       -0.135873
# 11                      -2.073075                        0.340982
# 12                       0.262200                       -0.140764
# 13                       0.493718                       -0.067719
# 14                      -0.047846                        0.123066
# 15                       0.583692                       -0.125119
# 16                      -2.321871                       -0.174086
# 17                       0.927106                        0.317207
# 18                      -0.023490                       -0.462643
# 19                      -0.082210                       -0.045797
# 20                      -0.261855                       -0.765663
# 21                      -0.308319                        0.186963
# 22                       0.104031                       -0.249702
# 23                       0.071925                        0.452510
# 24                       0.018212                        0.375076
#
#     UACC3133-311Cas9-RepB-P6_Avana-4  LU139-311cas9-RepB-p5_Avana-4  \
# 0                          -0.033800                      -0.085320
# 1                          -0.743975                      -0.155078
# 2                           0.607852                      -1.211994
# 3                           0.068720                      -0.918813
# 4                           0.053813                      -0.300063
# 5                           0.024631                      -0.358011
# 6                           0.101226                       0.830775
# 7                          -0.240883                       0.145043
# 8                          -0.214951                       0.204190
# 9                           0.173787                       0.590183
# 10                         -0.166875                      -0.608890
# 11                         -0.482057                      -0.560355
# 12                         -0.269960                       0.280478
# 13                          0.121145                       0.507900
# 14                         -0.069430                      -0.441613
# 15                          0.175140                       0.930648
# 16                          0.251679                      -0.998448
# 17                          0.651329                       0.371616
# 18                         -0.448888                       0.216329
# 19                         -0.010068                      -0.268610
# 20                         -0.054371                       0.702716
# 21                          0.134091                      -0.697935
# 22                         -0.007388                       0.081621
# 23                          0.405720                      -0.099228
# 24                          0.053847                      -0.062934
#
#     UPMM3-311cas9-RepA-p4_Avana-4  UACC3199-311cas9-RepA-p4_Avana-4  \
# 0                       -0.644091                         -0.174569
# 1                       -0.690596                         -0.232494
# 2                       -0.030394                          0.071135
# 3                       -0.843293                         -0.216612
# 4                       -0.188982                          0.218309
# 5                       -0.006433                          0.467287
# 6                        0.152045                          0.135000
# 7                        0.258763                          0.080839
# 8                       -0.200871                         -0.086072
# 9                        0.087866                         -0.021700
# 10                       0.194702                          0.013508
# 11                      -0.972836                         -0.134485
# 12                       0.526638                          0.019305
# 13                       0.230731                          0.157770
# 14                      -0.119981                         -0.437781
# 15                      -0.031481                          0.125114
# 16                      -0.149437                          0.296838
# 17                      -0.368324                          0.548127
# 18                      -1.163962                          0.024756
# 19                      -0.223380                          0.103540
# 20                      -0.326505                         -0.228108
# 21                      -0.696788                         -0.013862
# 22                      -0.588074                         -0.268655
# 23                      -0.149377                          0.111188
# 24                       0.048811                          0.118474
#
#     UACC3199-311cas9-RepB-p4_Avana-4
# 0                          -0.096824
# 1                          -0.472361
# 2                          -0.128212
# 3                          -0.447530
# 4                           0.120868
# 5                           0.005282
# 6                          -0.275124
# 7                          -0.062581
# 8                          -0.028628
# 9                           0.248652
# 10                          0.026179
# 11                         -0.486443
# 12                          0.139980
# 13                          0.078493
# 14                         -0.325847
# 15                         -0.042452
# 16                         -0.327778
# 17                          0.455950
# 18                          0.335640
# 19                          0.006669
# 20                         -0.025674
# 21                         -0.108231
# 22                          0.308304
# 23                          0.151631
# 24                          0.025461
#
# [25 rows x 2282 columns]

# %%
library_data = pd.read_csv("../../CRISPR-KO-library-refinement-pipeline/public_crispr_library/avana_library.tsv", sep ="\t", header = None)
library_data.columns = ['sgRNA', 'spacer', 'gene']
library_data.shape
# Out:
# (71826, 3)

# %%
lfc = pd.merge(lfc_data, library_data, how="left", on="spacer").set_index(['sgRNA', 'spacer', 'gene']).sort_values(by="gene")
lfc
# Out:
#                                     Colo699-311cas9-RepA-p6_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                        -0.257686
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                         0.233408
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                         0.023756
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                         0.014280
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                         0.054652
# ...                                                             ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                         -0.347602
#          TTTTACCTTGTTCACATGGA NaN                          0.085937
#          TTTTGACTCTAATCACCGGT NaN                          0.004612
#          TTTTTAATACAAGGTAATCT NaN                         -0.007124
#          TTTTTCTCACCCGATGAATC NaN                          0.033292
#
#                                     Colo699-311cas9-RepB-p6_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                        -0.298174
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                         0.299895
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                        -0.473843
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                        -0.324734
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                        -0.087523
# ...                                                             ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                          0.320081
#          TTTTACCTTGTTCACATGGA NaN                          0.292619
#          TTTTGACTCTAATCACCGGT NaN                         -0.385894
#          TTTTTAATACAAGGTAATCT NaN                          0.154439
#          TTTTTCTCACCCGATGAATC NaN                         -0.138348
#
#                                     HSB-2-311cas9_RepA_p4_Avana-3  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                       0.226088
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                       0.425173
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                      -0.419967
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                       0.235696
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                      -0.405659
# ...                                                           ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                       -0.042124
#          TTTTACCTTGTTCACATGGA NaN                        0.207097
#          TTTTGACTCTAATCACCGGT NaN                        0.182117
#          TTTTTAATACAAGGTAATCT NaN                       -0.221927
#          TTTTTCTCACCCGATGAATC NaN                       -0.256905
#
#                                     HSB-2-311cas9_RepB_p4_Avana-3  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                       0.030155
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                       0.251597
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                      -0.159187
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                      -0.686056
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                      -0.322912
# ...                                                           ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                       -0.290717
#          TTTTACCTTGTTCACATGGA NaN                        0.210888
#          TTTTGACTCTAATCACCGGT NaN                        0.221753
#          TTTTTAATACAAGGTAATCT NaN                       -0.152003
#          TTTTTCTCACCCGATGAATC NaN                       -0.251676
#
#                                     NCIH1339-311Cas9_RepA_p6_Avana-3  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                          0.195384
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                         -0.004233
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                          0.235672
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                          0.011473
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                         -0.210814
# ...                                                              ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                           0.046998
#          TTTTACCTTGTTCACATGGA NaN                           0.370268
#          TTTTGACTCTAATCACCGGT NaN                           0.040495
#          TTTTTAATACAAGGTAATCT NaN                          -0.017926
#          TTTTTCTCACCCGATGAATC NaN                           0.045482
#
#                                     NCIH1339-311Cas9_RepB_p6_Avana-3  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                          0.133835
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                          0.286380
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                         -0.039435
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                          0.555823
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                         -0.459552
# ...                                                              ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                           0.254702
#          TTTTACCTTGTTCACATGGA NaN                           0.229956
#          TTTTGACTCTAATCACCGGT NaN                           0.248597
#          TTTTTAATACAAGGTAATCT NaN                          -0.023821
#          TTTTTCTCACCCGATGAATC NaN                           0.018681
#
#                                     HEL-311Cas9_RepA_p4_Avana-3  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                    -0.486207
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                     0.763289
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                    -0.748898
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                     0.539960
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                     0.111614
# ...                                                         ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                      0.245870
#          TTTTACCTTGTTCACATGGA NaN                      0.645514
#          TTTTGACTCTAATCACCGGT NaN                     -0.529600
#          TTTTTAATACAAGGTAATCT NaN                      0.243133
#          TTTTTCTCACCCGATGAATC NaN                     -0.424483
#
#                                     HEL-311Cas9_RepB_p4_Avana-3  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                     0.694723
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                     0.849438
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                    -1.164373
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                    -0.144617
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                     0.007001
# ...                                                         ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                      0.194475
#          TTTTACCTTGTTCACATGGA NaN                     -0.280722
#          TTTTGACTCTAATCACCGGT NaN                      0.492304
#          TTTTTAATACAAGGTAATCT NaN                      0.246475
#          TTTTTCTCACCCGATGAATC NaN                      0.027706
#
#                                     HEL9217-311Cas9_RepA_p6_Avana-3  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                        -0.131924
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                         0.640287
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                        -0.783291
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                        -0.274605
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                         0.111214
# ...                                                             ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                         -0.006228
#          TTTTACCTTGTTCACATGGA NaN                          0.123187
#          TTTTGACTCTAATCACCGGT NaN                         -0.375254
#          TTTTTAATACAAGGTAATCT NaN                         -0.199168
#          TTTTTCTCACCCGATGAATC NaN                         -0.145190
#
#                                     HEL9217-311Cas9_RepB_p6_Avana-3  ...  \
# sgRNA    spacer               gene                                   ...
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                         0.168396  ...
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                         0.614076  ...
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                         0.260619  ...
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                        -0.983247  ...
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                         0.101652  ...
# ...                                                             ...  ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                          0.383855  ...
#          TTTTACCTTGTTCACATGGA NaN                          0.540023  ...
#          TTTTGACTCTAATCACCGGT NaN                         -0.202999  ...
#          TTTTTAATACAAGGTAATCT NaN                          0.037512  ...
#          TTTTTCTCACCCGATGAATC NaN                         -0.500957  ...
#
#                                     SNU977-311Cas9-AVANA-RepA-p6_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                              0.640012
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                              0.094097
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                             -0.693027
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                             -0.229447
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                             -0.003429
# ...                                                                  ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                               0.094468
#          TTTTACCTTGTTCACATGGA NaN                              -0.069548
#          TTTTGACTCTAATCACCGGT NaN                              -0.184673
#          TTTTTAATACAAGGTAATCT NaN                               0.234315
#          TTTTTCTCACCCGATGAATC NaN                              -0.476836
#
#                                     SNU977-311Cas9-AVANA-RepB-p6_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                             -0.122386
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                              0.183966
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                              0.173740
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                             -0.346081
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                             -0.030701
# ...                                                                  ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                              -0.100206
#          TTTTACCTTGTTCACATGGA NaN                               0.524311
#          TTTTGACTCTAATCACCGGT NaN                               0.040639
#          TTTTTAATACAAGGTAATCT NaN                               0.351794
#          TTTTTCTCACCCGATGAATC NaN                              -0.035720
#
#                                     HMMME-311cas9-RepA-p6_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                       0.141036
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                       0.541924
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                      -0.011650
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                       0.284870
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                      -0.092308
# ...                                                           ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                        0.086426
#          TTTTACCTTGTTCACATGGA NaN                        0.552081
#          TTTTGACTCTAATCACCGGT NaN                        0.789736
#          TTTTTAATACAAGGTAATCT NaN                        0.506071
#          TTTTTCTCACCCGATGAATC NaN                        0.462974
#
#                                     HMMME-311cas9-RepB-p6_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                      -0.424162
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                       0.343706
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                      -0.085083
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                       0.208857
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                      -0.223659
# ...                                                           ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                        0.051500
#          TTTTACCTTGTTCACATGGA NaN                        0.566581
#          TTTTGACTCTAATCACCGGT NaN                        0.703709
#          TTTTTAATACAAGGTAATCT NaN                        0.574097
#          TTTTTCTCACCCGATGAATC NaN                        0.332863
#
#                                     JVE528-311cas9-RepB-p6_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                        0.032231
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                        0.550545
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                       -0.348693
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                       -0.202541
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                       -0.349543
# ...                                                            ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                        -0.281878
#          TTTTACCTTGTTCACATGGA NaN                        -0.002678
#          TTTTGACTCTAATCACCGGT NaN                        -0.154770
#          TTTTTAATACAAGGTAATCT NaN                         0.049695
#          TTTTTCTCACCCGATGAATC NaN                        -0.122152
#
#                                     UACC3133-311Cas9-RepB-P6_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                          0.083409
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                          0.529825
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                          0.109986
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                         -0.440205
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                          0.028470
# ...                                                              ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                           0.337269
#          TTTTACCTTGTTCACATGGA NaN                          -0.152102
#          TTTTGACTCTAATCACCGGT NaN                          -0.152544
#          TTTTTAATACAAGGTAATCT NaN                          -0.155627
#          TTTTTCTCACCCGATGAATC NaN                           0.092295
#
#                                     LU139-311cas9-RepB-p5_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                       0.510994
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                       0.369991
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                       0.013164
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                       0.795404
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                      -0.159144
# ...                                                           ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                       -0.150301
#          TTTTACCTTGTTCACATGGA NaN                        0.565606
#          TTTTGACTCTAATCACCGGT NaN                        0.600969
#          TTTTTAATACAAGGTAATCT NaN                        0.397617
#          TTTTTCTCACCCGATGAATC NaN                        0.514143
#
#                                     UPMM3-311cas9-RepA-p4_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                       0.184200
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                       0.258753
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                       0.066177
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                       0.112115
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                      -0.411926
# ...                                                           ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                       -0.103350
#          TTTTACCTTGTTCACATGGA NaN                        0.080177
#          TTTTGACTCTAATCACCGGT NaN                        0.533769
#          TTTTTAATACAAGGTAATCT NaN                        0.393637
#          TTTTTCTCACCCGATGAATC NaN                        0.169668
#
#                                     UACC3199-311cas9-RepA-p4_Avana-4  \
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                          0.204731
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                          0.387107
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                          0.104395
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                          0.087137
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                         -0.176334
# ...                                                              ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                          -0.005658
#          TTTTACCTTGTTCACATGGA NaN                           0.013954
#          TTTTGACTCTAATCACCGGT NaN                           0.334734
#          TTTTTAATACAAGGTAATCT NaN                           0.208943
#          TTTTTCTCACCCGATGAATC NaN                           0.063161
#
#                                     UACC3199-311cas9-RepB-p4_Avana-4
# sgRNA    spacer               gene
# sgA1BG_1 GGAAGTCTGGAGTCTCCAGG A1BG                         -0.018663
# sgA1BG_2 GTGGACTTCCAGCTACGGCG A1BG                          0.412849
# sgA1BG_4 TCAATGGTCACAGTAGCGCT A1BG                          0.095047
# sgA1BG_3 GTGTGCCGAGGTGTGCTGCG A1BG                          0.055744
# sgA1CF_2 GGAATCAAATCACAAATCCG A1CF                          0.079386
# ...                                                              ...
# NaN      TTTGTGTATTACCTCAGGAA NaN                           0.281344
#          TTTTACCTTGTTCACATGGA NaN                           0.195993
#          TTTTGACTCTAATCACCGGT NaN                           0.061219
#          TTTTTAATACAAGGTAATCT NaN                           0.141980
#          TTTTTCTCACCCGATGAATC NaN                          -0.237517
#
# [76427 rows x 2281 columns]

# %%
# normalize data by median
lfc_norm = lfc.apply(normalize_column, axis=0)

# %%
lfc_norm_scaled, list_common_essential = scale_essential(lfc)
sanity_check_scale_essential(lfc_norm, lfc_norm_scaled, list_common_essential)
# Out:
# Scale factor:  1.2376473275775624
# /tmp/ipykernel_1041239/2939665036.py:38: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([ess_before, ess_after], labels = ['Before', 'After'])

# %%
lfc_norm_scaled_avg = mean_row(lfc_norm_scaled)
lfc_norm_scaled_avg = lfc_norm_scaled_avg.reset_index()
lfc_norm_scaled_avg
# Out:
#           sgRNA                spacer  gene      mean
# 0      sgA1BG_1  GGAAGTCTGGAGTCTCCAGG  A1BG  0.000033
# 1      sgA1BG_2  GTGGACTTCCAGCTACGGCG  A1BG  0.241808
# 2      sgA1BG_4  TCAATGGTCACAGTAGCGCT  A1BG -0.089741
# 3      sgA1BG_3  GTGTGCCGAGGTGTGCTGCG  A1BG  0.051367
# 4      sgA1CF_2  GGAATCAAATCACAAATCCG  A1CF -0.096843
# ...         ...                   ...   ...       ...
# 76422       NaN  TTTGTGTATTACCTCAGGAA   NaN  0.015253
# 76423       NaN  TTTTACCTTGTTCACATGGA   NaN  0.335777
# 76424       NaN  TTTTGACTCTAATCACCGGT   NaN  0.173447
# 76425       NaN  TTTTTAATACAAGGTAATCT   NaN  0.248071
# 76426       NaN  TTTTTCTCACCCGATGAATC   NaN  0.171397
#
# [76427 rows x 4 columns]

# %%
lfc_norm_scaled_avg.to_csv("./normalized/avana_normalized_lfc.csv", index=False)
